# %% [markdown]
# # Real Estate data visualisations using matplotlib

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd

# %reload_ext autoreload
# %autoreload 2

# %%
#load csv
real_df = pd.read_csv('../data/Real estate.csv')
real_df
# Out:
#       No  X1 transaction date  X2 house age  \
# 0      1             2012.917          32.0
# 1      2             2012.917          19.5
# 2      3             2013.583          13.3
# 3      4             2013.500          13.3
# 4      5             2012.833           5.0
# ..   ...                  ...           ...
# 409  410             2013.000          13.7
# 410  411             2012.667           5.6
# 411  412             2013.250          18.8
# 412  413             2013.000           8.1
# 413  414             2013.500           6.5
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                  84.87882                               10
# 1                                 306.59470                                9
# 2                                 561.98450                                5
# 3                                 561.98450                                5
# ...

# %%
# rename columns
real_df.rename(columns={
    'X1 transaction date': 'TransactionDate',
    'X2 house age' : 'HouseAge',
    'X3 distance to the nearest MRT station':'DistanceFromStation',
    'X4 number of convenience stores':'NumberOfStores',
    'X5 latitude':'Latitude',
    'X6 longitude':'Longitude',
    'Y house price of unit area':'PricePerUnitArea'
    
}, inplace=True)
# Out:
#       No  TransactionDate  HouseAge  DistanceFromStation  NumberOfStores  \
# 0      1         2012.917      32.0             84.87882              10
# 1      2         2012.917      19.5            306.59470               9
# 2      3         2013.583      13.3            561.98450               5
# 3      4         2013.500      13.3            561.98450               5
# 4      5         2012.833       5.0            390.56840               5
# ..   ...              ...       ...                  ...             ...
# 409  410         2013.000      13.7           4082.01500               0
# 410  411         2012.667       5.6             90.45606               9
# 411  412         2013.250      18.8            390.96960               7
# 412  413         2013.000       8.1            104.81010               5
# 413  414         2013.500       6.5             90.45606               9
#
#      Latitude  Longitude  PricePerUnitArea
# 0    24.98298  121.54024              37.9
# ...

# %% [markdown]
# # Plotting

# %%
#sort
real_df = real_df.sort_values(by='TransactionDate')


df = real_df.values
date = real_array[:,1]
price = real_array[:,7]
real_df
# Out:
#       No  TransactionDate  HouseAge  DistanceFromStation  NumberOfStores  \
# 293  294         2012.667      12.6             383.2805               7
# 134  135         2012.667      33.4             186.9686               6
# 383  384         2012.667      29.1             506.1144               4
# 203  204         2012.667      15.6             289.3248               5
# 149  150         2012.667      34.9             179.4538               8
# ..   ...              ...       ...                  ...             ...
# 63    64         2013.583       2.6             533.4762               4
# 76    77         2013.583      35.9             616.4004               3
# 72    73         2013.583      32.5             424.5442               8
# 156  157         2013.583      30.7            1264.7300               0
# 310  311         2013.583      16.4            1643.4990               2
#
#      Latitude  Longitude  PricePerUnitArea
# 293  24.96735  121.54464              42.5
# ...
